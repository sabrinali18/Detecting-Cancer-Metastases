# %% [markdown]
# ## Setup

# %%
# Install the OpenSlide C library and Python bindings
# !apt-get install openslide-tools
# !pip install openslide-python

# %%
import os
import random
import numpy as np
import tensorflow as tf

from PIL import Image
from skimage.color import rgb2gray

# %matplotlib inline
import matplotlib.pyplot as plt
from openslide import open_slide, __library_version__ as openslide_version

# %%
# functions provided by Joshua Gordon
def read_slide(slide, x, y, level, width, height, as_float=False):
    im = slide.read_region((x,y), level, (width, height))
    im = im.convert('RGB') # drop the alpha channel
    if as_float:
        im = np.asarray(im, dtype=np.float32)
    else:
        im = np.asarray(im)
    assert im.shape == (height, width, 3)
    return im

def find_tissue_pixels(image, intensity=0.8):
    im_gray = rgb2gray(image)
    assert im_gray.shape == (image.shape[0], image.shape[1])
    indices = np.where(im_gray <= intensity)
    return zip(indices[0], indices[1])

def apply_mask(im, mask, color=(255,0,0)):
    masked = np.copy(im)
    for x,y in mask: masked[x][y] = color
    return masked

# %% [markdown]
# ## Download Data
# Skip this section if you already have data in the Google Drive

# %%
#read data from google bucket
slides_num = ['002', '012', '016', '019', '023', '031', '035', '057', '059', '064', '075', '078', '081', '084', '091', '094', '101']
data_url = 'https://storage.googleapis.com/applied-deep-learning/Final_Project/'
slides_path = [('tumor_' + num + '.tif') for num in slides_num]
tumor_masks_path = [('tumor_' + num + '_mask.tif') for num in slides_num]

slides = []
tumor_masks = []

for sp in slides_path:
  if not os.path.exists(sp):
    slide_url = data_url+sp
    # !curl -O $slide_url
  slides.append(open_slide(sp))
  
for tmp in tumor_masks_path:
  if not os.path.exists(tmp):
    mask_url = data_url+tmp
    # !curl -O $mask_url
  tumor_masks.append(open_slide(tmp))

# %%
# !ls
# Out:
# sample_data	    tumor_023.tif	tumor_064.tif	    tumor_091.tif
# tumor_002_mask.tif  tumor_031_mask.tif	tumor_075_mask.tif  tumor_094_mask.tif
# tumor_002.tif	    tumor_031.tif	tumor_075.tif	    tumor_094.tif
# tumor_012_mask.tif  tumor_035_mask.tif	tumor_078_mask.tif  tumor_101_mask.tif
# tumor_012.tif	    tumor_035.tif	tumor_078.tif	    tumor_101.tif
# tumor_016_mask.tif  tumor_057_mask.tif	tumor_081_mask.tif  tumor_110_mask.tif
# tumor_016.tif	    tumor_057.tif	tumor_081.tif	    tumor_110.tif
# tumor_019_mask.tif  tumor_059_mask.tif	tumor_084_mask.tif
# tumor_019.tif	    tumor_059.tif	tumor_084.tif
# tumor_023_mask.tif  tumor_064_mask.tif	tumor_091_mask.tif

# %%
# Verify downsampling works as expected
for slide in slides:
  width, height = slide.level_dimensions[7]
  assert width * slide.level_downsamples[7] == slide.level_dimensions[0][0]
  assert height * slide.level_downsamples[7] == slide.level_dimensions[0][1]

# %%
# Take a look at all slides at level 5
for slide, tumor_mask, slide_num in zip(slides, tumor_masks, slides_num):
  slide_image = read_slide(slide, 
                           x=0, 
                           y=0, 
                           level=5, 
                           width=slide.level_dimensions[5][0], 
                           height=slide.level_dimensions[5][1])
  mask_image = read_slide(tumor_mask, 
                          x=0, 
                          y=0, 
                          level=5, 
                          width=slide.level_dimensions[5][0], 
                          height=slide.level_dimensions[5][1])
  mask_image = mask_image[:,:,0]

  plt.figure(figsize=(6, 6), dpi=100)
  plt.title("slide {}".format(slide_num))
  plt.imshow(slide_image)
  plt.imshow(mask_image, cmap='jet', alpha=0.5)

# %% [markdown]
# ## Generating Dataset
# Skip this section if you already have data in the Google Drive

# %%
def is_tumor_at_center(mask, center_size):
  patch_size = mask.shape[0]
  offset = (patch_size - center_size) // 2
  n_tumor_pixels = np.sum(mask[offset:offset + center_size, offset:offset + center_size])
  return n_tumor_pixels > 0

def get_patch(slide, tumor_mask, x, y, level, patch_size):
  # get patch centered at (x, y)
  
  x, y = int(x), int(y)
  half_patch_len = int(patch_size // 2 * slide.level_downsamples[level])
  
  slide_image = read_slide(slide, 
                           x - half_patch_len, 
                           y - half_patch_len, 
                           level, 
                           width=patch_size, 
                           height=patch_size)
  mask_image = read_slide(tumor_mask, 
                          x - half_patch_len, 
                          y - half_patch_len, 
                          level, 
                          width=patch_size, 
                          height=patch_size)
  mask_image = mask_image[:, :, 0]
  return slide_image, mask_image

def get_pixels(slide, tumor_mask, checking_level, half_patch_len):
    assert slide.level_dimensions[checking_level] == tumor_mask.level_dimensions[checking_level]
    slide_image = read_slide(slide,
                             x=0,
                             y=0,
                             level=checking_level,
                             width=slide.level_dimensions[checking_level][0],
                             height=slide.level_dimensions[checking_level][1])
    mask_image = read_slide(tumor_mask,
                            x=0,
                            y=0,
                            level=checking_level,
                            width=tumor_mask.level_dimensions[checking_level][0],
                            height=tumor_mask.level_dimensions[checking_level][1])
    mask_image = mask_image[:,:,0]
    
    slide_image_cropped = slide_image[half_patch_len:-half_patch_len, half_patch_len:-half_patch_len]
    mask_image_cropped  = mask_image[half_patch_len:-half_patch_len, half_patch_len:-half_patch_len]
    
    tissue_pixels = find_tissue_pixels(slide_image_cropped)
    tissue_mask = apply_mask(slide_image_cropped, tissue_pixels)
    
    # list of (x, y)
    normal_pixels = list(zip(*np.nonzero(tissue_mask[:, :, 0] - 255 * mask_image_cropped)))
    tumor_pixels = list(zip(*np.nonzero(mask_image_cropped)))
    
    return normal_pixels, tumor_pixels

def generate_dataset(slides, tumor_masks,
                     level1, level2,
                     checking_level,
                     n_data=2500,
                     patch_size=299,
                     center_size=128):
  """
  inputs:
    slides:
      list of openslide files, of tissues
    tumor_masks:
      list of openslide files, of tumor masks
    level1, level2:
      int, zoom levels
    n_data:
      int, number of data points
    patch_size:
      int, size of the square patch extracted from slides
    center_size:
      int, size of the square center in the patch
  outputs:
    X1:
      np.array of patches at zoom level1
    X2:
      np.array of patches at zoom level2
    y:
      np.array of labels
  """
  assert n_data % 2 == 0
  
  # check which slides have tumors using tumor mask at a certain level
  checking_level = checking_level
  half_patch_len = patch_size // 2
  
  slide_has_normal_pixels = np.zeros(len(slides)).astype(bool)
  slide_has_tumor_pixels = np.zeros(len(tumor_masks)).astype(bool)
  
  for i, (slide, tumor_mask) in enumerate(zip(slides, tumor_masks)):
    normal_pixels, tumor_pixels = get_pixels(slide, tumor_mask, checking_level, half_patch_len)
    slide_has_normal_pixels[i] = normal_pixels is not None
    slide_has_tumor_pixels[i] = tumor_pixels is not None
  
  X1 = []
  X2 = []
  X1_mask = []
  X2_mask = []
  Y = []
  
  slide_has_normal_pixels = slide_has_normal_pixels.astype(float)
  slide_has_tumor_pixels = slide_has_tumor_pixels.astype(float)
  slide_normal_p = slide_has_normal_pixels / np.sum(slide_has_normal_pixels)
  slide_tumor_p = slide_has_tumor_pixels / np.sum(slide_has_tumor_pixels)
  
  
  n_normal_data_on_each_slide = np.random.multinomial(n_data / 2, slide_normal_p)
  n_tumor_data_on_each_slide = np.random.multinomial(n_data / 2, slide_tumor_p)

  for i, (slide, tumor_mask, n_normal_data, n_tumor_data) in \
    enumerate(zip(slides, tumor_masks, n_normal_data_on_each_slide, n_tumor_data_on_each_slide)):

    print("process slide {:>4d} / {}".format(i + 1, len(slides)))

    normal_pixels, tumor_pixels = get_pixels(slide, tumor_mask, checking_level, half_patch_len)
    normal_pixels = [(x + half_patch_len, y + half_patch_len) for y, x in normal_pixels]
    tumor_pixels = [(x + half_patch_len, y + half_patch_len) for y, x in tumor_pixels]
 
    for i in range(n_normal_data + n_tumor_data):

      choose_tumor = i < n_normal_data
      chosen_pixels = tumor_pixels if choose_tumor else normal_pixels

      # randomly choose one patch from the chosen slide
      found_patch = False
      while not found_patch:
        x, y = random.choice(chosen_pixels)
        x = x * slide.level_downsamples[checking_level]
        y = y * slide.level_downsamples[checking_level]

        patch_image1, patch_mask1 = get_patch(slide, tumor_mask, x, y, level1, patch_size)

        exist_tumor = is_tumor_at_center(patch_mask1, center_size)

        tissue_pixels = find_tissue_pixels(patch_image1)
        tissue_percentage = float(len(list(tissue_pixels))) / patch_size**2 * 100

        if tissue_percentage > 50 and exist_tumor == choose_tumor:
          found_patch = True

          patch_image2, patch_mask2 = get_patch(slide, tumor_mask, x, y, level2, patch_size)
          X1.append(patch_image1)
          X2.append(patch_image2)
          X1_mask.append(patch_mask1)
          X2_mask.append(patch_mask2)
          Y.append(int(choose_tumor))
        
  X1, X2, X1_mask, X2_mask, Y = np.array(X1), np.array(X2), np.array(X1_mask), np.array(X2_mask), np.array(Y)
  return X1, X2, X1_mask, X2_mask, Y

# %%
LEVEL1 = 5
LEVEL2 = 6
CHECKING_LEVEL = 5

n_train = 800
n_test = 200

training_slides_num = ['016', '019', '031', '064', '075', '078', '084', '094', '101']
testing_slides_num = ['091']
training_slides = [slides[slides_num.index(num)] for num in training_slides_num]
testing_slides = [slides[slides_num.index(num)] for num in testing_slides_num]
training_masks = [tumor_masks[slides_num.index(num)] for num in training_slides_num]
testing_masks = [tumor_masks[slides_num.index(num)] for num in testing_slides_num]

print("Generating Training Data")
X1_train, X2_train, X1_mask_train, X2_mask_train, y_train = \
  generate_dataset(training_slides, training_masks, LEVEL1, LEVEL2, CHECKING_LEVEL, n_data=900)
print("Generating Testing Data")
X1_test, X2_test, X1_mask_test, X2_mask_test, y_test = \
  generate_dataset(testing_slides, testing_masks, LEVEL1, LEVEL2, CHECKING_LEVEL, n_data=100)
# Out:
# Generating Training Data
# process slide    1 / 9
# process slide    2 / 9
# process slide    3 / 9
# process slide    4 / 9
# process slide    5 / 9
# process slide    6 / 9
# process slide    7 / 9
# process slide    8 / 9
# process slide    9 / 9
# Generating Testing Data
# process slide    1 / 1

# %%
print("Training Data")
print(X1_train.shape, X2_train.shape, X1_mask_train.shape, X2_mask_train.shape, y_train.shape)
print("Testing Data")
print(X1_test.shape, X2_test.shape, X1_mask_test.shape, X2_mask_test.shape, y_test.shape)
# Out:
# Training Data
# ((900, 299, 299, 3), (900, 299, 299, 3), (900, 299, 299), (900, 299, 299), (900,))
# Testing Data
# ((100, 299, 299, 3), (100, 299, 299, 3), (100, 299, 299), (100, 299, 299), (100,))

# %%
i = 3
x1, x2, label = X1_train[i], X2_train[i], y_train[i]
plt.subplot(1, 2, 1)
plt.imshow(x1)
plt.subplot(1, 2, 2)
plt.imshow(x2)
print(label)
# Out:
# 1

# %% [markdown]
# ## Save Data to Google Drive
# Skip this section if you already have data in the Google Drive

# %%
#get access to google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
def upload_images(X1, X2, X1_mask, X2_mask, y, level1, level2, is_train=True):
  """
  upload images to google drive
  """

  drive_dir = '/content/gdrive/My Drive'
  main_dir = os.path.join(drive_dir, 'ADL_Project')
  sub_dir = os.path.join(main_dir, 'train' if is_train else 'test')
  
  if not os.path.exists(drive_dir):
    raise ValueError('not connected to Google drive')
  if not os.path.exists(main_dir):
    os.mkdir(main_dir)
  if not os.path.exists(sub_dir):
    os.mkdir(sub_dir)
    
  np.save(os.path.join(sub_dir, 'X1'), X1)
  np.save(os.path.join(sub_dir, 'X2'), X2)
  np.save(os.path.join(sub_dir, 'X1_mask'), X1_mask)
  np.save(os.path.join(sub_dir, 'X2_mask'), X2_mask)
  np.save(os.path.join(sub_dir, 'y'), y)

  local_path_X1 = os.path.join(sub_dir, 'level{}'.format(level1))
  local_path_X2 = os.path.join(sub_dir, 'level{}'.format(level2))
  
  if not os.path.exists(local_path_X1):
    os.mkdir(local_path_X1)
  if not os.path.exists(local_path_X2):
    os.mkdir(local_path_X2)
  
  normal_idx = 0
  tumor_idx = 0
  for X1i, X2i, yi in zip(X1, X2, y):
    im_X1 = Image.fromarray(X1i)
    im_X2 = Image.fromarray(X2i)

    if yi == 0:
      idx = normal_idx
      normal_idx += 1
      local_path_X1i = os.path.join(local_path_X1, 'normal')
      local_path_X2i = os.path.join(local_path_X2, 'normal')
    else:
      idx = tumor_idx
      tumor_idx += 1
      local_path_X1i = os.path.join(local_path_X1, 'tumor')
      local_path_X2i = os.path.join(local_path_X2, 'tumor')
      
    if not os.path.exists(local_path_X1i):
      os.mkdir(local_path_X1i)
    if not os.path.exists(local_path_X2i):
      os.mkdir(local_path_X2i)

    local_file_name_X1 = '{:04d}.jpg'.format(idx)
    local_file_name_X2 = '{:04d}.jpg'.format(idx)

    local_file_path_X1 = os.path.join(local_path_X1i, local_file_name_X1)
    local_file_path_X2 = os.path.join(local_path_X2i, local_file_name_X2)

    im_X1.save(local_file_path_X1)
    im_X2.save(local_file_path_X2)

# %%
upload_images(X1_train, X2_train, X1_mask_train, X2_mask_train, y_train, LEVEL1, LEVEL2, is_train_set=True)
upload_images(X1_test, X2_test, X1_mask_test, X2_mask_test, y_test, LEVEL1, LEVEL2, is_train_set=False)

# %% [markdown]
# ## Load Data from Google Drive

# %%
#get access to google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
train_dir = '/content/gdrive/My Drive/ADL_Project/train'
test_dir = '/content/gdrive/My Drive/ADL_Project/test'
assert os.path.exists(train_dir)
assert os.path.exists(test_dir)

X1_train, X2_train, y_train = np.load(train_dir + '/X1.npy'), np.load(train_dir + '/X2.npy'), np.load(train_dir + '/y.npy')
X1_test, X2_test, y_test = np.load(test_dir + '/X1.npy'), np.load(test_dir + '/X2.npy'), np.load(test_dir + '/y.npy')
X1_train, X2_train = X1_train.astype('float32'), X2_train.astype('float32')
X1_test, X2_test = X1_test.astype('float32'), X2_test.astype('float32')

# %% [markdown]
# ## Prepare Data Generators
# To enable that the ImageDataGenerator will apply the same preprocessing to both input images, rewrite a customized ImageDataGenerator.

# %%
from keras.preprocessing.image import NumpyArrayIterator, ImageDataGenerator

class CustomizedNumpyArrayIterator(NumpyArrayIterator):
  def _get_batches_of_transformed_samples(self, index_array):
    batch_x = np.zeros(tuple([len(index_array)] + list(self.x.shape)[1:]), dtype=self.dtype)
    batch_x_miscs = []
    if not self.x_misc:
      batch_x_miscs = [np.zeros(tuple([len(index_array)] + list(xx.shape)[1:]), dtype=self.dtype) for xx in self.x_misc]
    for i, j in enumerate(index_array):
      x = self.x[j]
      params = self.image_data_generator.get_random_transform(x.shape)
      x = self.image_data_generator.apply_transform(x.astype(self.dtype), params)
      x = self.image_data_generator.standardize(x)
      batch_x[i] = x
      for k, xx in enumerate(self.x_misc):
        x = xx[j]
        x = self.image_data_generator.apply_transform(x.astype(self.dtype), params)
        x = self.image_data_generator.standardize(x)
        batch_x_miscs[k][i] = x

    output = (batch_x if batch_x_miscs == [] else [batch_x] + batch_x_miscs,)
    if self.y is None:
      return output[0]

    output += (self.y[index_array],)

    return output
  
class CustomizedImageDataGenerator(ImageDataGenerator):
  def flow(self,
           x,
           y=None,
           batch_size=32,
           shuffle=True,
           sample_weight=None,
           seed=None,
           save_to_dir=None,
           save_prefix='',
           save_format='png',
           subset=None):
    return NumpyArrayIterator(
      x,
      y,
      self,
      batch_size=batch_size,
      shuffle=shuffle,
      sample_weight=sample_weight,
      seed=seed,
      data_format=self.data_format,
      save_to_dir=save_to_dir,
      save_prefix=save_prefix,
      save_format=save_format,
      subset=subset
    )

def get_generator(X1, X2, y, is_train=True):
  """
  input: slides_dir: directory of slides
         masks_dir: directory of masks
         default upload from google drive
  """
  if is_train:
    data_gen_args = dict(horizontal_flip=True,
                         vertical_flip=True,
                         rotation_range=90,
                         width_shift_range=(-8, 8),
                         height_shift_range=(-8, 8),
                         brightness_range=(0, 64./255),
                         
                        )
  else:
    data_gen_args = dict(rescale=1./255)

  data_gen = CustomizedImageDataGenerator(**data_gen_args)

  seed = 0

  data_generator = data_gen.flow((X1, X2), y, shuffle=True, seed=seed)

  return data_generator
# Out:
# Using TensorFlow backend.

# %%
train_generator = get_generator(X1_train, X2_train, y_train, is_train=True)
test_generator = get_generator(X1_test, X2_test, y_test, is_train=False)

# %% [markdown]
# ## Model

# %%
from keras.models import Model
from keras.layers import Flatten, Input, Dense, Dropout
from keras.layers import concatenate
from keras.applications.inception_v3 import InceptionV3

PATCH_SIZE = 299

def multi_scale_model():
  conv_base_1 = InceptionV3(weights='imagenet',
                            include_top=False,
                            input_shape=(PATCH_SIZE, PATCH_SIZE, 3))
  conv_base_2 = InceptionV3(weights='imagenet',
                            include_top=False,
                            input_shape=(PATCH_SIZE, PATCH_SIZE, 3))
  conv_base_1.trainable = False
  conv_base_2.trainable = False

  # to avoid name conflict
  conv_base_1.name = conv_base_1.name + "_base_1"
  conv_base_1.name = conv_base_2.name + "_base_2"
  
  for layer1, layer2 in zip(conv_base_1.layers, conv_base_2.layers):
    layer1.name = layer1.name + "_base_1"
    layer2.name = layer2.name + "_base_2"
    
  in1, feature1 = conv_base_1.input, conv_base_1.output
  in2, feature2 = conv_base_2.input, conv_base_2.output
  
  flat1 = Flatten()(feature1)
  flat2 = Flatten()(feature2)
  flat = concatenate([flat1, flat2])

  dense = Dense(256, activation='relu')(flat)
  dense = Dropout(.5)(dense)
  out = Dense(1, activation='sigmoid')(dense)

  model = Model([in1, in2], out)
  return model

# %%
from keras.optimizers import Adam

BATCH_SIZE = 32
EPOCHS = 30
LR = 1e-4
monitor = 'val_loss'

model = multi_scale_model()
model.compile(Adam(lr=LR),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# prepare dir to save weights
import datetime
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

date = str(datetime.datetime.now())
date = 'D' + date[2:4] + date[5:7] + date[8:10] + '_' + date[11:13] + date[14:16] + date[17:19]

weight_dir = '/content/gdrive/My Drive/ADL_Project/weights'
log_dir = os.path.join(weight_dir, date)
weight_file = os.path.join(log_dir, 'weights.h5')
if not os.path.exists(weight_dir):
  os.mkdir(weight_dir)
if not os.path.exists(log_dir):
  os.mkdir(log_dir)

# call back functions
model_checkpoint = ModelCheckpoint(weight_file, verbose=1, mode='auto',
                                   monitor=monitor, save_best_only=True, save_weights_only=True)
reduce_lr = ReduceLROnPlateau(monitor=monitor, patience=15, mode='auto',
                              factor=0.7, cooldown=0, min_lr=1e-5, verbose=2)
callback_list = [model_checkpoint, reduce_lr]
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1_base_1 (InputLayer)     (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# input_2_base_2 (InputLayer)     (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# conv2d_1_base_1 (Conv2D)        (None, 149, 149, 32) 864         input_1_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_95_base_2 (Conv2D)       (None, 149, 149, 32) 864         input_2_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1_base_1 (B (None, 149, 149, 32) 96          conv2d_1_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95_base_2 ( (None, 149, 149, 32) 96          conv2d_95_base_2[0][0]
# __________________________________________________________________________________________________
# activation_1_base_1 (Activation (None, 149, 149, 32) 0           batch_normalization_1_base_1[0][0
# __________________________________________________________________________________________________
# activation_95_base_2 (Activatio (None, 149, 149, 32) 0           batch_normalization_95_base_2[0][
# __________________________________________________________________________________________________
# conv2d_2_base_1 (Conv2D)        (None, 147, 147, 32) 9216        activation_1_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_96_base_2 (Conv2D)       (None, 147, 147, 32) 9216        activation_95_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2_base_1 (B (None, 147, 147, 32) 96          conv2d_2_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96_base_2 ( (None, 147, 147, 32) 96          conv2d_96_base_2[0][0]
# __________________________________________________________________________________________________
# activation_2_base_1 (Activation (None, 147, 147, 32) 0           batch_normalization_2_base_1[0][0
# __________________________________________________________________________________________________
# activation_96_base_2 (Activatio (None, 147, 147, 32) 0           batch_normalization_96_base_2[0][
# __________________________________________________________________________________________________
# conv2d_3_base_1 (Conv2D)        (None, 147, 147, 64) 18432       activation_2_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_97_base_2 (Conv2D)       (None, 147, 147, 64) 18432       activation_96_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3_base_1 (B (None, 147, 147, 64) 192         conv2d_3_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97_base_2 ( (None, 147, 147, 64) 192         conv2d_97_base_2[0][0]
# __________________________________________________________________________________________________
# activation_3_base_1 (Activation (None, 147, 147, 64) 0           batch_normalization_3_base_1[0][0
# __________________________________________________________________________________________________
# activation_97_base_2 (Activatio (None, 147, 147, 64) 0           batch_normalization_97_base_2[0][
# __________________________________________________________________________________________________
# max_pooling2d_1_base_1 (MaxPool (None, 73, 73, 64)   0           activation_3_base_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5_base_2 (MaxPool (None, 73, 73, 64)   0           activation_97_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4_base_1 (Conv2D)        (None, 73, 73, 80)   5120        max_pooling2d_1_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_98_base_2 (Conv2D)       (None, 73, 73, 80)   5120        max_pooling2d_5_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4_base_1 (B (None, 73, 73, 80)   240         conv2d_4_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98_base_2 ( (None, 73, 73, 80)   240         conv2d_98_base_2[0][0]
# __________________________________________________________________________________________________
# activation_4_base_1 (Activation (None, 73, 73, 80)   0           batch_normalization_4_base_1[0][0
# __________________________________________________________________________________________________
# activation_98_base_2 (Activatio (None, 73, 73, 80)   0           batch_normalization_98_base_2[0][
# __________________________________________________________________________________________________
# conv2d_5_base_1 (Conv2D)        (None, 71, 71, 192)  138240      activation_4_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_99_base_2 (Conv2D)       (None, 71, 71, 192)  138240      activation_98_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5_base_1 (B (None, 71, 71, 192)  576         conv2d_5_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99_base_2 ( (None, 71, 71, 192)  576         conv2d_99_base_2[0][0]
# __________________________________________________________________________________________________
# activation_5_base_1 (Activation (None, 71, 71, 192)  0           batch_normalization_5_base_1[0][0
# __________________________________________________________________________________________________
# activation_99_base_2 (Activatio (None, 71, 71, 192)  0           batch_normalization_99_base_2[0][
# __________________________________________________________________________________________________
# max_pooling2d_2_base_1 (MaxPool (None, 35, 35, 192)  0           activation_5_base_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6_base_2 (MaxPool (None, 35, 35, 192)  0           activation_99_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9_base_1 (Conv2D)        (None, 35, 35, 64)   12288       max_pooling2d_2_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_103_base_2 (Conv2D)      (None, 35, 35, 64)   12288       max_pooling2d_6_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9_base_1 (B (None, 35, 35, 64)   192         conv2d_9_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103_base_2  (None, 35, 35, 64)   192         conv2d_103_base_2[0][0]
# __________________________________________________________________________________________________
# activation_9_base_1 (Activation (None, 35, 35, 64)   0           batch_normalization_9_base_1[0][0
# __________________________________________________________________________________________________
# activation_103_base_2 (Activati (None, 35, 35, 64)   0           batch_normalization_103_base_2[0]
# __________________________________________________________________________________________________
# conv2d_7_base_1 (Conv2D)        (None, 35, 35, 48)   9216        max_pooling2d_2_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10_base_1 (Conv2D)       (None, 35, 35, 96)   55296       activation_9_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_101_base_2 (Conv2D)      (None, 35, 35, 48)   9216        max_pooling2d_6_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_104_base_2 (Conv2D)      (None, 35, 35, 96)   55296       activation_103_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7_base_1 (B (None, 35, 35, 48)   144         conv2d_7_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10_base_1 ( (None, 35, 35, 96)   288         conv2d_10_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101_base_2  (None, 35, 35, 48)   144         conv2d_101_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104_base_2  (None, 35, 35, 96)   288         conv2d_104_base_2[0][0]
# __________________________________________________________________________________________________
# activation_7_base_1 (Activation (None, 35, 35, 48)   0           batch_normalization_7_base_1[0][0
# __________________________________________________________________________________________________
# activation_10_base_1 (Activatio (None, 35, 35, 96)   0           batch_normalization_10_base_1[0][
# __________________________________________________________________________________________________
# average_pooling2d_1_base_1 (Ave (None, 35, 35, 192)  0           max_pooling2d_2_base_1[0][0]
# __________________________________________________________________________________________________
# activation_101_base_2 (Activati (None, 35, 35, 48)   0           batch_normalization_101_base_2[0]
# __________________________________________________________________________________________________
# activation_104_base_2 (Activati (None, 35, 35, 96)   0           batch_normalization_104_base_2[0]
# __________________________________________________________________________________________________
# average_pooling2d_10_base_2 (Av (None, 35, 35, 192)  0           max_pooling2d_6_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6_base_1 (Conv2D)        (None, 35, 35, 64)   12288       max_pooling2d_2_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8_base_1 (Conv2D)        (None, 35, 35, 64)   76800       activation_7_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11_base_1 (Conv2D)       (None, 35, 35, 96)   82944       activation_10_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12_base_1 (Conv2D)       (None, 35, 35, 32)   6144        average_pooling2d_1_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_100_base_2 (Conv2D)      (None, 35, 35, 64)   12288       max_pooling2d_6_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_102_base_2 (Conv2D)      (None, 35, 35, 64)   76800       activation_101_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_105_base_2 (Conv2D)      (None, 35, 35, 96)   82944       activation_104_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_106_base_2 (Conv2D)      (None, 35, 35, 32)   6144        average_pooling2d_10_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6_base_1 (B (None, 35, 35, 64)   192         conv2d_6_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8_base_1 (B (None, 35, 35, 64)   192         conv2d_8_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11_base_1 ( (None, 35, 35, 96)   288         conv2d_11_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12_base_1 ( (None, 35, 35, 32)   96          conv2d_12_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100_base_2  (None, 35, 35, 64)   192         conv2d_100_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102_base_2  (None, 35, 35, 64)   192         conv2d_102_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105_base_2  (None, 35, 35, 96)   288         conv2d_105_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106_base_2  (None, 35, 35, 32)   96          conv2d_106_base_2[0][0]
# __________________________________________________________________________________________________
# activation_6_base_1 (Activation (None, 35, 35, 64)   0           batch_normalization_6_base_1[0][0
# __________________________________________________________________________________________________
# activation_8_base_1 (Activation (None, 35, 35, 64)   0           batch_normalization_8_base_1[0][0
# __________________________________________________________________________________________________
# activation_11_base_1 (Activatio (None, 35, 35, 96)   0           batch_normalization_11_base_1[0][
# __________________________________________________________________________________________________
# activation_12_base_1 (Activatio (None, 35, 35, 32)   0           batch_normalization_12_base_1[0][
# __________________________________________________________________________________________________
# activation_100_base_2 (Activati (None, 35, 35, 64)   0           batch_normalization_100_base_2[0]
# __________________________________________________________________________________________________
# activation_102_base_2 (Activati (None, 35, 35, 64)   0           batch_normalization_102_base_2[0]
# __________________________________________________________________________________________________
# activation_105_base_2 (Activati (None, 35, 35, 96)   0           batch_normalization_105_base_2[0]
# __________________________________________________________________________________________________
# activation_106_base_2 (Activati (None, 35, 35, 32)   0           batch_normalization_106_base_2[0]
# __________________________________________________________________________________________________
# mixed0_base_1 (Concatenate)     (None, 35, 35, 256)  0           activation_6_base_1[0][0]
#                                                                  activation_8_base_1[0][0]
#                                                                  activation_11_base_1[0][0]
#                                                                  activation_12_base_1[0][0]
# __________________________________________________________________________________________________
# mixed0_base_2 (Concatenate)     (None, 35, 35, 256)  0           activation_100_base_2[0][0]
#                                                                  activation_102_base_2[0][0]
#                                                                  activation_105_base_2[0][0]
#                                                                  activation_106_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16_base_1 (Conv2D)       (None, 35, 35, 64)   16384       mixed0_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_110_base_2 (Conv2D)      (None, 35, 35, 64)   16384       mixed0_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16_base_1 ( (None, 35, 35, 64)   192         conv2d_16_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110_base_2  (None, 35, 35, 64)   192         conv2d_110_base_2[0][0]
# __________________________________________________________________________________________________
# activation_16_base_1 (Activatio (None, 35, 35, 64)   0           batch_normalization_16_base_1[0][
# __________________________________________________________________________________________________
# activation_110_base_2 (Activati (None, 35, 35, 64)   0           batch_normalization_110_base_2[0]
# __________________________________________________________________________________________________
# conv2d_14_base_1 (Conv2D)       (None, 35, 35, 48)   12288       mixed0_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_17_base_1 (Conv2D)       (None, 35, 35, 96)   55296       activation_16_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_108_base_2 (Conv2D)      (None, 35, 35, 48)   12288       mixed0_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_111_base_2 (Conv2D)      (None, 35, 35, 96)   55296       activation_110_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14_base_1 ( (None, 35, 35, 48)   144         conv2d_14_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17_base_1 ( (None, 35, 35, 96)   288         conv2d_17_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108_base_2  (None, 35, 35, 48)   144         conv2d_108_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111_base_2  (None, 35, 35, 96)   288         conv2d_111_base_2[0][0]
# __________________________________________________________________________________________________
# activation_14_base_1 (Activatio (None, 35, 35, 48)   0           batch_normalization_14_base_1[0][
# __________________________________________________________________________________________________
# activation_17_base_1 (Activatio (None, 35, 35, 96)   0           batch_normalization_17_base_1[0][
# __________________________________________________________________________________________________
# average_pooling2d_2_base_1 (Ave (None, 35, 35, 256)  0           mixed0_base_1[0][0]
# __________________________________________________________________________________________________
# activation_108_base_2 (Activati (None, 35, 35, 48)   0           batch_normalization_108_base_2[0]
# __________________________________________________________________________________________________
# activation_111_base_2 (Activati (None, 35, 35, 96)   0           batch_normalization_111_base_2[0]
# __________________________________________________________________________________________________
# average_pooling2d_11_base_2 (Av (None, 35, 35, 256)  0           mixed0_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13_base_1 (Conv2D)       (None, 35, 35, 64)   16384       mixed0_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15_base_1 (Conv2D)       (None, 35, 35, 64)   76800       activation_14_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_18_base_1 (Conv2D)       (None, 35, 35, 96)   82944       activation_17_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_19_base_1 (Conv2D)       (None, 35, 35, 64)   16384       average_pooling2d_2_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_107_base_2 (Conv2D)      (None, 35, 35, 64)   16384       mixed0_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_109_base_2 (Conv2D)      (None, 35, 35, 64)   76800       activation_108_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_112_base_2 (Conv2D)      (None, 35, 35, 96)   82944       activation_111_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_113_base_2 (Conv2D)      (None, 35, 35, 64)   16384       average_pooling2d_11_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13_base_1 ( (None, 35, 35, 64)   192         conv2d_13_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15_base_1 ( (None, 35, 35, 64)   192         conv2d_15_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18_base_1 ( (None, 35, 35, 96)   288         conv2d_18_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19_base_1 ( (None, 35, 35, 64)   192         conv2d_19_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107_base_2  (None, 35, 35, 64)   192         conv2d_107_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109_base_2  (None, 35, 35, 64)   192         conv2d_109_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112_base_2  (None, 35, 35, 96)   288         conv2d_112_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113_base_2  (None, 35, 35, 64)   192         conv2d_113_base_2[0][0]
# __________________________________________________________________________________________________
# activation_13_base_1 (Activatio (None, 35, 35, 64)   0           batch_normalization_13_base_1[0][
# __________________________________________________________________________________________________
# activation_15_base_1 (Activatio (None, 35, 35, 64)   0           batch_normalization_15_base_1[0][
# __________________________________________________________________________________________________
# activation_18_base_1 (Activatio (None, 35, 35, 96)   0           batch_normalization_18_base_1[0][
# __________________________________________________________________________________________________
# activation_19_base_1 (Activatio (None, 35, 35, 64)   0           batch_normalization_19_base_1[0][
# __________________________________________________________________________________________________
# activation_107_base_2 (Activati (None, 35, 35, 64)   0           batch_normalization_107_base_2[0]
# __________________________________________________________________________________________________
# activation_109_base_2 (Activati (None, 35, 35, 64)   0           batch_normalization_109_base_2[0]
# __________________________________________________________________________________________________
# activation_112_base_2 (Activati (None, 35, 35, 96)   0           batch_normalization_112_base_2[0]
# __________________________________________________________________________________________________
# activation_113_base_2 (Activati (None, 35, 35, 64)   0           batch_normalization_113_base_2[0]
# __________________________________________________________________________________________________
# mixed1_base_1 (Concatenate)     (None, 35, 35, 288)  0           activation_13_base_1[0][0]
#                                                                  activation_15_base_1[0][0]
#                                                                  activation_18_base_1[0][0]
#                                                                  activation_19_base_1[0][0]
# __________________________________________________________________________________________________
# mixed1_base_2 (Concatenate)     (None, 35, 35, 288)  0           activation_107_base_2[0][0]
#                                                                  activation_109_base_2[0][0]
#                                                                  activation_112_base_2[0][0]
#                                                                  activation_113_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_23_base_1 (Conv2D)       (None, 35, 35, 64)   18432       mixed1_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_117_base_2 (Conv2D)      (None, 35, 35, 64)   18432       mixed1_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23_base_1 ( (None, 35, 35, 64)   192         conv2d_23_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117_base_2  (None, 35, 35, 64)   192         conv2d_117_base_2[0][0]
# __________________________________________________________________________________________________
# activation_23_base_1 (Activatio (None, 35, 35, 64)   0           batch_normalization_23_base_1[0][
# __________________________________________________________________________________________________
# activation_117_base_2 (Activati (None, 35, 35, 64)   0           batch_normalization_117_base_2[0]
# __________________________________________________________________________________________________
# conv2d_21_base_1 (Conv2D)       (None, 35, 35, 48)   13824       mixed1_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_24_base_1 (Conv2D)       (None, 35, 35, 96)   55296       activation_23_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_115_base_2 (Conv2D)      (None, 35, 35, 48)   13824       mixed1_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_118_base_2 (Conv2D)      (None, 35, 35, 96)   55296       activation_117_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21_base_1 ( (None, 35, 35, 48)   144         conv2d_21_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24_base_1 ( (None, 35, 35, 96)   288         conv2d_24_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115_base_2  (None, 35, 35, 48)   144         conv2d_115_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118_base_2  (None, 35, 35, 96)   288         conv2d_118_base_2[0][0]
# __________________________________________________________________________________________________
# activation_21_base_1 (Activatio (None, 35, 35, 48)   0           batch_normalization_21_base_1[0][
# __________________________________________________________________________________________________
# activation_24_base_1 (Activatio (None, 35, 35, 96)   0           batch_normalization_24_base_1[0][
# __________________________________________________________________________________________________
# average_pooling2d_3_base_1 (Ave (None, 35, 35, 288)  0           mixed1_base_1[0][0]
# __________________________________________________________________________________________________
# activation_115_base_2 (Activati (None, 35, 35, 48)   0           batch_normalization_115_base_2[0]
# __________________________________________________________________________________________________
# activation_118_base_2 (Activati (None, 35, 35, 96)   0           batch_normalization_118_base_2[0]
# __________________________________________________________________________________________________
# average_pooling2d_12_base_2 (Av (None, 35, 35, 288)  0           mixed1_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_20_base_1 (Conv2D)       (None, 35, 35, 64)   18432       mixed1_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_22_base_1 (Conv2D)       (None, 35, 35, 64)   76800       activation_21_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_25_base_1 (Conv2D)       (None, 35, 35, 96)   82944       activation_24_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_26_base_1 (Conv2D)       (None, 35, 35, 64)   18432       average_pooling2d_3_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_114_base_2 (Conv2D)      (None, 35, 35, 64)   18432       mixed1_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_116_base_2 (Conv2D)      (None, 35, 35, 64)   76800       activation_115_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_119_base_2 (Conv2D)      (None, 35, 35, 96)   82944       activation_118_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_120_base_2 (Conv2D)      (None, 35, 35, 64)   18432       average_pooling2d_12_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20_base_1 ( (None, 35, 35, 64)   192         conv2d_20_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22_base_1 ( (None, 35, 35, 64)   192         conv2d_22_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25_base_1 ( (None, 35, 35, 96)   288         conv2d_25_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26_base_1 ( (None, 35, 35, 64)   192         conv2d_26_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114_base_2  (None, 35, 35, 64)   192         conv2d_114_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116_base_2  (None, 35, 35, 64)   192         conv2d_116_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119_base_2  (None, 35, 35, 96)   288         conv2d_119_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120_base_2  (None, 35, 35, 64)   192         conv2d_120_base_2[0][0]
# __________________________________________________________________________________________________
# activation_20_base_1 (Activatio (None, 35, 35, 64)   0           batch_normalization_20_base_1[0][
# __________________________________________________________________________________________________
# activation_22_base_1 (Activatio (None, 35, 35, 64)   0           batch_normalization_22_base_1[0][
# __________________________________________________________________________________________________
# activation_25_base_1 (Activatio (None, 35, 35, 96)   0           batch_normalization_25_base_1[0][
# __________________________________________________________________________________________________
# activation_26_base_1 (Activatio (None, 35, 35, 64)   0           batch_normalization_26_base_1[0][
# __________________________________________________________________________________________________
# activation_114_base_2 (Activati (None, 35, 35, 64)   0           batch_normalization_114_base_2[0]
# __________________________________________________________________________________________________
# activation_116_base_2 (Activati (None, 35, 35, 64)   0           batch_normalization_116_base_2[0]
# __________________________________________________________________________________________________
# activation_119_base_2 (Activati (None, 35, 35, 96)   0           batch_normalization_119_base_2[0]
# __________________________________________________________________________________________________
# activation_120_base_2 (Activati (None, 35, 35, 64)   0           batch_normalization_120_base_2[0]
# __________________________________________________________________________________________________
# mixed2_base_1 (Concatenate)     (None, 35, 35, 288)  0           activation_20_base_1[0][0]
#                                                                  activation_22_base_1[0][0]
#                                                                  activation_25_base_1[0][0]
#                                                                  activation_26_base_1[0][0]
# __________________________________________________________________________________________________
# mixed2_base_2 (Concatenate)     (None, 35, 35, 288)  0           activation_114_base_2[0][0]
#                                                                  activation_116_base_2[0][0]
#                                                                  activation_119_base_2[0][0]
#                                                                  activation_120_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_28_base_1 (Conv2D)       (None, 35, 35, 64)   18432       mixed2_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_122_base_2 (Conv2D)      (None, 35, 35, 64)   18432       mixed2_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28_base_1 ( (None, 35, 35, 64)   192         conv2d_28_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122_base_2  (None, 35, 35, 64)   192         conv2d_122_base_2[0][0]
# __________________________________________________________________________________________________
# activation_28_base_1 (Activatio (None, 35, 35, 64)   0           batch_normalization_28_base_1[0][
# __________________________________________________________________________________________________
# activation_122_base_2 (Activati (None, 35, 35, 64)   0           batch_normalization_122_base_2[0]
# __________________________________________________________________________________________________
# conv2d_29_base_1 (Conv2D)       (None, 35, 35, 96)   55296       activation_28_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_123_base_2 (Conv2D)      (None, 35, 35, 96)   55296       activation_122_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29_base_1 ( (None, 35, 35, 96)   288         conv2d_29_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123_base_2  (None, 35, 35, 96)   288         conv2d_123_base_2[0][0]
# __________________________________________________________________________________________________
# activation_29_base_1 (Activatio (None, 35, 35, 96)   0           batch_normalization_29_base_1[0][
# __________________________________________________________________________________________________
# activation_123_base_2 (Activati (None, 35, 35, 96)   0           batch_normalization_123_base_2[0]
# __________________________________________________________________________________________________
# conv2d_27_base_1 (Conv2D)       (None, 17, 17, 384)  995328      mixed2_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_30_base_1 (Conv2D)       (None, 17, 17, 96)   82944       activation_29_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_121_base_2 (Conv2D)      (None, 17, 17, 384)  995328      mixed2_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_124_base_2 (Conv2D)      (None, 17, 17, 96)   82944       activation_123_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27_base_1 ( (None, 17, 17, 384)  1152        conv2d_27_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30_base_1 ( (None, 17, 17, 96)   288         conv2d_30_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121_base_2  (None, 17, 17, 384)  1152        conv2d_121_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124_base_2  (None, 17, 17, 96)   288         conv2d_124_base_2[0][0]
# __________________________________________________________________________________________________
# activation_27_base_1 (Activatio (None, 17, 17, 384)  0           batch_normalization_27_base_1[0][
# __________________________________________________________________________________________________
# activation_30_base_1 (Activatio (None, 17, 17, 96)   0           batch_normalization_30_base_1[0][
# __________________________________________________________________________________________________
# max_pooling2d_3_base_1 (MaxPool (None, 17, 17, 288)  0           mixed2_base_1[0][0]
# __________________________________________________________________________________________________
# activation_121_base_2 (Activati (None, 17, 17, 384)  0           batch_normalization_121_base_2[0]
# __________________________________________________________________________________________________
# activation_124_base_2 (Activati (None, 17, 17, 96)   0           batch_normalization_124_base_2[0]
# __________________________________________________________________________________________________
# max_pooling2d_7_base_2 (MaxPool (None, 17, 17, 288)  0           mixed2_base_2[0][0]
# __________________________________________________________________________________________________
# mixed3_base_1 (Concatenate)     (None, 17, 17, 768)  0           activation_27_base_1[0][0]
#                                                                  activation_30_base_1[0][0]
#                                                                  max_pooling2d_3_base_1[0][0]
# __________________________________________________________________________________________________
# mixed3_base_2 (Concatenate)     (None, 17, 17, 768)  0           activation_121_base_2[0][0]
#                                                                  activation_124_base_2[0][0]
#                                                                  max_pooling2d_7_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_35_base_1 (Conv2D)       (None, 17, 17, 128)  98304       mixed3_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_129_base_2 (Conv2D)      (None, 17, 17, 128)  98304       mixed3_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35_base_1 ( (None, 17, 17, 128)  384         conv2d_35_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129_base_2  (None, 17, 17, 128)  384         conv2d_129_base_2[0][0]
# __________________________________________________________________________________________________
# activation_35_base_1 (Activatio (None, 17, 17, 128)  0           batch_normalization_35_base_1[0][
# __________________________________________________________________________________________________
# activation_129_base_2 (Activati (None, 17, 17, 128)  0           batch_normalization_129_base_2[0]
# __________________________________________________________________________________________________
# conv2d_36_base_1 (Conv2D)       (None, 17, 17, 128)  114688      activation_35_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_130_base_2 (Conv2D)      (None, 17, 17, 128)  114688      activation_129_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36_base_1 ( (None, 17, 17, 128)  384         conv2d_36_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130_base_2  (None, 17, 17, 128)  384         conv2d_130_base_2[0][0]
# __________________________________________________________________________________________________
# activation_36_base_1 (Activatio (None, 17, 17, 128)  0           batch_normalization_36_base_1[0][
# __________________________________________________________________________________________________
# activation_130_base_2 (Activati (None, 17, 17, 128)  0           batch_normalization_130_base_2[0]
# __________________________________________________________________________________________________
# conv2d_32_base_1 (Conv2D)       (None, 17, 17, 128)  98304       mixed3_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_37_base_1 (Conv2D)       (None, 17, 17, 128)  114688      activation_36_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_126_base_2 (Conv2D)      (None, 17, 17, 128)  98304       mixed3_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_131_base_2 (Conv2D)      (None, 17, 17, 128)  114688      activation_130_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32_base_1 ( (None, 17, 17, 128)  384         conv2d_32_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37_base_1 ( (None, 17, 17, 128)  384         conv2d_37_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126_base_2  (None, 17, 17, 128)  384         conv2d_126_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131_base_2  (None, 17, 17, 128)  384         conv2d_131_base_2[0][0]
# __________________________________________________________________________________________________
# activation_32_base_1 (Activatio (None, 17, 17, 128)  0           batch_normalization_32_base_1[0][
# __________________________________________________________________________________________________
# activation_37_base_1 (Activatio (None, 17, 17, 128)  0           batch_normalization_37_base_1[0][
# __________________________________________________________________________________________________
# activation_126_base_2 (Activati (None, 17, 17, 128)  0           batch_normalization_126_base_2[0]
# __________________________________________________________________________________________________
# activation_131_base_2 (Activati (None, 17, 17, 128)  0           batch_normalization_131_base_2[0]
# __________________________________________________________________________________________________
# conv2d_33_base_1 (Conv2D)       (None, 17, 17, 128)  114688      activation_32_base_1[0][0]
# ...
# activation_179_base_2 (Activati (None, 8, 8, 192)    0           batch_normalization_179_base_2[0]
# __________________________________________________________________________________________________
# mixed9_base_1 (Concatenate)     (None, 8, 8, 2048)   0           activation_77_base_1[0][0]
#                                                                  mixed9_0_base_1[0][0]
#                                                                  concatenate_1_base_1[0][0]
#                                                                  activation_85_base_1[0][0]
# __________________________________________________________________________________________________
# mixed9_base_2 (Concatenate)     (None, 8, 8, 2048)   0           activation_171_base_2[0][0]
#                                                                  mixed9_0_base_2[0][0]
#                                                                  concatenate_3_base_2[0][0]
#                                                                  activation_179_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_90_base_1 (Conv2D)       (None, 8, 8, 448)    917504      mixed9_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_184_base_2 (Conv2D)      (None, 8, 8, 448)    917504      mixed9_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90_base_1 ( (None, 8, 8, 448)    1344        conv2d_90_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_184_base_2  (None, 8, 8, 448)    1344        conv2d_184_base_2[0][0]
# __________________________________________________________________________________________________
# activation_90_base_1 (Activatio (None, 8, 8, 448)    0           batch_normalization_90_base_1[0][
# __________________________________________________________________________________________________
# activation_184_base_2 (Activati (None, 8, 8, 448)    0           batch_normalization_184_base_2[0]
# __________________________________________________________________________________________________
# conv2d_87_base_1 (Conv2D)       (None, 8, 8, 384)    786432      mixed9_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_91_base_1 (Conv2D)       (None, 8, 8, 384)    1548288     activation_90_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_181_base_2 (Conv2D)      (None, 8, 8, 384)    786432      mixed9_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_185_base_2 (Conv2D)      (None, 8, 8, 384)    1548288     activation_184_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87_base_1 ( (None, 8, 8, 384)    1152        conv2d_87_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91_base_1 ( (None, 8, 8, 384)    1152        conv2d_91_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_181_base_2  (None, 8, 8, 384)    1152        conv2d_181_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_185_base_2  (None, 8, 8, 384)    1152        conv2d_185_base_2[0][0]
# __________________________________________________________________________________________________
# activation_87_base_1 (Activatio (None, 8, 8, 384)    0           batch_normalization_87_base_1[0][
# __________________________________________________________________________________________________
# activation_91_base_1 (Activatio (None, 8, 8, 384)    0           batch_normalization_91_base_1[0][
# __________________________________________________________________________________________________
# activation_181_base_2 (Activati (None, 8, 8, 384)    0           batch_normalization_181_base_2[0]
# __________________________________________________________________________________________________
# activation_185_base_2 (Activati (None, 8, 8, 384)    0           batch_normalization_185_base_2[0]
# __________________________________________________________________________________________________
# conv2d_88_base_1 (Conv2D)       (None, 8, 8, 384)    442368      activation_87_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_89_base_1 (Conv2D)       (None, 8, 8, 384)    442368      activation_87_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_92_base_1 (Conv2D)       (None, 8, 8, 384)    442368      activation_91_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_93_base_1 (Conv2D)       (None, 8, 8, 384)    442368      activation_91_base_1[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9_base_1 (Ave (None, 8, 8, 2048)   0           mixed9_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_182_base_2 (Conv2D)      (None, 8, 8, 384)    442368      activation_181_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_183_base_2 (Conv2D)      (None, 8, 8, 384)    442368      activation_181_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_186_base_2 (Conv2D)      (None, 8, 8, 384)    442368      activation_185_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_187_base_2 (Conv2D)      (None, 8, 8, 384)    442368      activation_185_base_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_18_base_2 (Av (None, 8, 8, 2048)   0           mixed9_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_86_base_1 (Conv2D)       (None, 8, 8, 320)    655360      mixed9_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88_base_1 ( (None, 8, 8, 384)    1152        conv2d_88_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89_base_1 ( (None, 8, 8, 384)    1152        conv2d_89_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92_base_1 ( (None, 8, 8, 384)    1152        conv2d_92_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93_base_1 ( (None, 8, 8, 384)    1152        conv2d_93_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_94_base_1 (Conv2D)       (None, 8, 8, 192)    393216      average_pooling2d_9_base_1[0][0]
# __________________________________________________________________________________________________
# conv2d_180_base_2 (Conv2D)      (None, 8, 8, 320)    655360      mixed9_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_182_base_2  (None, 8, 8, 384)    1152        conv2d_182_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_183_base_2  (None, 8, 8, 384)    1152        conv2d_183_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_186_base_2  (None, 8, 8, 384)    1152        conv2d_186_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187_base_2  (None, 8, 8, 384)    1152        conv2d_187_base_2[0][0]
# __________________________________________________________________________________________________
# conv2d_188_base_2 (Conv2D)      (None, 8, 8, 192)    393216      average_pooling2d_18_base_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86_base_1 ( (None, 8, 8, 320)    960         conv2d_86_base_1[0][0]
# __________________________________________________________________________________________________
# activation_88_base_1 (Activatio (None, 8, 8, 384)    0           batch_normalization_88_base_1[0][
# __________________________________________________________________________________________________
# activation_89_base_1 (Activatio (None, 8, 8, 384)    0           batch_normalization_89_base_1[0][
# __________________________________________________________________________________________________
# activation_92_base_1 (Activatio (None, 8, 8, 384)    0           batch_normalization_92_base_1[0][
# __________________________________________________________________________________________________
# activation_93_base_1 (Activatio (None, 8, 8, 384)    0           batch_normalization_93_base_1[0][
# __________________________________________________________________________________________________
# batch_normalization_94_base_1 ( (None, 8, 8, 192)    576         conv2d_94_base_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_180_base_2  (None, 8, 8, 320)    960         conv2d_180_base_2[0][0]
# __________________________________________________________________________________________________
# activation_182_base_2 (Activati (None, 8, 8, 384)    0           batch_normalization_182_base_2[0]
# __________________________________________________________________________________________________
# activation_183_base_2 (Activati (None, 8, 8, 384)    0           batch_normalization_183_base_2[0]
# __________________________________________________________________________________________________
# activation_186_base_2 (Activati (None, 8, 8, 384)    0           batch_normalization_186_base_2[0]
# __________________________________________________________________________________________________
# activation_187_base_2 (Activati (None, 8, 8, 384)    0           batch_normalization_187_base_2[0]
# __________________________________________________________________________________________________
# batch_normalization_188_base_2  (None, 8, 8, 192)    576         conv2d_188_base_2[0][0]
# __________________________________________________________________________________________________
# activation_86_base_1 (Activatio (None, 8, 8, 320)    0           batch_normalization_86_base_1[0][
# __________________________________________________________________________________________________
# mixed9_1_base_1 (Concatenate)   (None, 8, 8, 768)    0           activation_88_base_1[0][0]
#                                                                  activation_89_base_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2_base_1 (Concatena (None, 8, 8, 768)    0           activation_92_base_1[0][0]
#                                                                  activation_93_base_1[0][0]
# __________________________________________________________________________________________________
# activation_94_base_1 (Activatio (None, 8, 8, 192)    0           batch_normalization_94_base_1[0][
# __________________________________________________________________________________________________
# activation_180_base_2 (Activati (None, 8, 8, 320)    0           batch_normalization_180_base_2[0]
# __________________________________________________________________________________________________
# mixed9_1_base_2 (Concatenate)   (None, 8, 8, 768)    0           activation_182_base_2[0][0]
#                                                                  activation_183_base_2[0][0]
# __________________________________________________________________________________________________
# concatenate_4_base_2 (Concatena (None, 8, 8, 768)    0           activation_186_base_2[0][0]
#                                                                  activation_187_base_2[0][0]
# __________________________________________________________________________________________________
# activation_188_base_2 (Activati (None, 8, 8, 192)    0           batch_normalization_188_base_2[0]
# __________________________________________________________________________________________________
# mixed10_base_1 (Concatenate)    (None, 8, 8, 2048)   0           activation_86_base_1[0][0]
#                                                                  mixed9_1_base_1[0][0]
#                                                                  concatenate_2_base_1[0][0]
#                                                                  activation_94_base_1[0][0]
# __________________________________________________________________________________________________
# mixed10_base_2 (Concatenate)    (None, 8, 8, 2048)   0           activation_180_base_2[0][0]
#                                                                  mixed9_1_base_2[0][0]
#                                                                  concatenate_4_base_2[0][0]
#                                                                  activation_188_base_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 131072)       0           mixed10_base_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 131072)       0           mixed10_base_2[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 262144)       0           flatten_1[0][0]
#                                                                  flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          67109120    concatenate_5[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            257         dropout_1[0][0]
# ==================================================================================================
# Total params: 110,714,945
# Trainable params: 110,646,081
# Non-trainable params: 68,864
# __________________________________________________________________________________________________

# %%
import math
history = model.fit_generator(train_generator,
                              steps_per_epoch=math.ceil(X1_train.shape[0] / BATCH_SIZE),
                              epochs=EPOCHS,
                              verbose=2,
                              callbacks=callback_list,
                              validation_data=test_generator,
                              validation_steps=math.ceil(X1_test.shape[0] / BATCH_SIZE))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/30
#  - 78s - loss: 2.1581 - acc: 0.6866 - val_loss: 1.9348 - val_acc: 0.6700
#
# Epoch 00001: val_loss improved from inf to 1.93478, saving model to /content/gdrive/My Drive/ADL_Project/weights/D190508_000014/weights.h5
# Epoch 2/30
#  - 32s - loss: 0.2093 - acc: 0.9345 - val_loss: 3.2231 - val_acc: 0.5900
#
# Epoch 00002: val_loss did not improve from 1.93478
# Epoch 3/30
#  - 32s - loss: 0.0535 - acc: 0.9860 - val_loss: 2.2164 - val_acc: 0.7300
#
# Epoch 00003: val_loss did not improve from 1.93478
# Epoch 4/30
#  - 31s - loss: 0.0138 - acc: 0.9924 - val_loss: 3.5673 - val_acc: 0.5800
#
# Epoch 00004: val_loss did not improve from 1.93478
# Epoch 5/30
#  - 32s - loss: 0.0060 - acc: 0.9978 - val_loss: 2.9399 - val_acc: 0.6100
#
# Epoch 00005: val_loss did not improve from 1.93478
# Epoch 6/30
#  - 32s - loss: 0.0023 - acc: 1.0000 - val_loss: 2.4762 - val_acc: 0.6700
#
# Epoch 00006: val_loss did not improve from 1.93478
# Epoch 7/30
#  - 32s - loss: 0.0014 - acc: 1.0000 - val_loss: 3.8331 - val_acc: 0.5700
#
# Epoch 00007: val_loss did not improve from 1.93478
# Epoch 8/30
#  - 32s - loss: 7.2154e-04 - acc: 1.0000 - val_loss: 4.3075 - val_acc: 0.5200
#
# Epoch 00008: val_loss did not improve from 1.93478
# Epoch 9/30
#  - 32s - loss: 3.3082e-04 - acc: 1.0000 - val_loss: 4.1807 - val_acc: 0.5300
#
# Epoch 00009: val_loss did not improve from 1.93478
# Epoch 10/30
#  - 32s - loss: 1.0581e-04 - acc: 1.0000 - val_loss: 4.0401 - val_acc: 0.5600
#
# Epoch 00010: val_loss did not improve from 1.93478
# Epoch 11/30
#  - 32s - loss: 3.9000e-04 - acc: 1.0000 - val_loss: 4.2364 - val_acc: 0.5400
#
# Epoch 00011: val_loss did not improve from 1.93478
# Epoch 12/30
#  - 32s - loss: 6.6233e-04 - acc: 1.0000 - val_loss: 4.5977 - val_acc: 0.5200
#
# Epoch 00012: val_loss did not improve from 1.93478
# Epoch 13/30
#  - 32s - loss: 1.5289e-04 - acc: 1.0000 - val_loss: 4.6864 - val_acc: 0.5200
#
# Epoch 00013: val_loss did not improve from 1.93478
# Epoch 14/30
#  - 32s - loss: 0.0018 - acc: 0.9989 - val_loss: 1.2676 - val_acc: 0.7000
#
# Epoch 00014: val_loss improved from 1.93478 to 1.26756, saving model to /content/gdrive/My Drive/ADL_Project/weights/D190508_000014/weights.h5
# Epoch 15/30
#  - 32s - loss: 0.0102 - acc: 0.9957 - val_loss: 3.1055 - val_acc: 0.6800
#
# Epoch 00015: val_loss did not improve from 1.26756
# Epoch 16/30
#  - 32s - loss: 8.4752e-04 - acc: 1.0000 - val_loss: 2.4048 - val_acc: 0.7300
#
# Epoch 00016: val_loss did not improve from 1.26756
# Epoch 17/30
#  - 32s - loss: 2.0412e-04 - acc: 1.0000 - val_loss: 2.5977 - val_acc: 0.7300
#
# Epoch 00017: val_loss did not improve from 1.26756
# Epoch 18/30
#  - 32s - loss: 0.0312 - acc: 0.9852 - val_loss: 3.1041 - val_acc: 0.7300
#
# Epoch 00018: val_loss did not improve from 1.26756
# Epoch 19/30
#  - 32s - loss: 0.0947 - acc: 0.9784 - val_loss: 3.8554 - val_acc: 0.7200
#
# Epoch 00019: val_loss did not improve from 1.26756
# Epoch 20/30
#  - 32s - loss: 0.1336 - acc: 0.9657 - val_loss: 1.6406 - val_acc: 0.7800
#
# Epoch 00020: val_loss did not improve from 1.26756
# Epoch 21/30
#  - 32s - loss: 0.2333 - acc: 0.9547 - val_loss: 1.3829 - val_acc: 0.8500
#
# Epoch 00021: val_loss did not improve from 1.26756
# Epoch 22/30
#  - 32s - loss: 0.1048 - acc: 0.9763 - val_loss: 3.2205 - val_acc: 0.7600
#
# Epoch 00022: val_loss did not improve from 1.26756
# Epoch 23/30
#  - 32s - loss: 0.0239 - acc: 0.9935 - val_loss: 1.9055 - val_acc: 0.7600
#
# Epoch 00023: val_loss did not improve from 1.26756
# Epoch 24/30
#  - 32s - loss: 0.0078 - acc: 0.9978 - val_loss: 2.0753 - val_acc: 0.7600
#
# Epoch 00024: val_loss did not improve from 1.26756
# Epoch 25/30
#  - 32s - loss: 0.0019 - acc: 1.0000 - val_loss: 2.1147 - val_acc: 0.7600
#
# Epoch 00025: val_loss did not improve from 1.26756
# Epoch 26/30
#  - 32s - loss: 0.0042 - acc: 0.9989 - val_loss: 1.7230 - val_acc: 0.7900
#
# Epoch 00026: val_loss did not improve from 1.26756
# Epoch 27/30
#  - 32s - loss: 0.0015 - acc: 1.0000 - val_loss: 1.8507 - val_acc: 0.7800
#
# Epoch 00027: val_loss did not improve from 1.26756
# Epoch 28/30
#  - 32s - loss: 1.2694e-04 - acc: 1.0000 - val_loss: 2.2247 - val_acc: 0.7700
#
# Epoch 00028: val_loss did not improve from 1.26756
# Epoch 29/30
#  - 32s - loss: 2.6199e-04 - acc: 1.0000 - val_loss: 2.2558 - val_acc: 0.7700
#
# Epoch 00029: val_loss did not improve from 1.26756
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 6.999999823165126e-05.
# Epoch 30/30
#  - 32s - loss: 4.2938e-04 - acc: 1.0000 - val_loss: 2.3942 - val_acc: 0.7600
#
# Epoch 00030: val_loss did not improve from 1.26756

# %%
def plot_history(train_hist, key=['acc', 'loss']):
  fig, axes = plt.subplots(1, 2, figsize = (20, 10))
